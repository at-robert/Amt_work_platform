# %%
import pandas

# %%
df = pandas.read_csv("Amtran.csv")

# %%
df
# Out:
#                                               Summary       Issue key  \
# 0                                散热块种类较多，不同散热块用不同颜色区分  GTBFO32U2P-412
# 1                4040 散热块厚度从2.0T变为1.0T 撕取时容易破损 太软不好贴附  GTBFO32U2P-411
# 2                                     FO32背板 左右泡棉贴附NG  GTBFO32U2P-410
# 3                                  FO32 DECO 尺寸变形度 NG  GTBFO32U2P-409
# 4                                             UM与实际不符  GTBFO32U2P-391
# 5    Daisy chain 功能输出信号连接MSI MPG321URX和MAG 321CUP时无画面  GTBFO32U2P-408
# 6   [OSD] F02 开启PBP功能时，主画面与子画面提示框位置都在中下方（主画面提示框位置对...  GTBFO32U2P-403
# 7              [SYS][Not Gating] KVM功能设置好后，选择KVM切换无作用  GTBFO32U2P-156
# 8   [SYS][Not Gating] HDMI2连接显卡RTX3080，HDMI连接ROG S...  GTBFO32U2P-221
# 9   [SYS][Not Gating] type-c连接笔记本ROG Strix G634JZ，...  GTBFO32U2P-227
# 10  [AUDIO][Not Gating] P07 连接耳机 （EDIFIER ，32欧），Au...  GTBFO32U2P-390
# 11  [SYS][Not Gating] 显示器连接20mHDMI线无法切到3840*2160@2...  GTBFO32U2P-279
# 12  [SYS][Not Gating] USB(A/C) Charge: OFF后 显示器待机后...   GTBFO32U2P-85
# 13  [SYS][Not Gating]菜单内开启FreeSync ，打开大摆钟测试，测试软件无法...  GTBFO32U2P-188
# 14         [OSD] Eagle Eye狙击镜点击开启后，下方多出两排空格，光标移动至下方空格  GTBFO32U2P-280
# 15  [OSD]  PIP/PBP开启，miniDP为主源，TYPE-C为子源，屏幕打开时主源mi...  GTBFO32U2P-347
# 16            [SYS] PIP/PBP开启后，切换到单窗口时，遮黑显示无信号后，画面再打开  GTBFO32U2P-294
# 17        [OSD] 按下五项键右按-e选择系统咨询窗开启后，退到上一级菜单时，右上角咨询窗闪烁   GTBFO32U2P-70
#
#     Issue id Issue Type    Status Project key           Project name  \
# 0     124424        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 1     124423        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 2     123943        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 3     123942        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 4     123023        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 5     123596        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 6     123402        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 7     120457        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 8     120711        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 9     120722        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 10    122996        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 11    121275        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 12    120237        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 13    120570        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 14    121288        Bug  Reopened  GTBFO32U2P  GIGABYTE FO32U2P_2023
# 15    122313        Bug      Open  GTBFO32U2P  GIGABYTE FO32U2P_2023
#
  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7    13/Jan/24 8:50 AM;64251bceb05b4e3e7dabeb51;问题已解决
# 8                                                 NaN
# 9   29/Jan/24 3:41 PM;557058:f2adca06-f342-4e6e-82...
# 10                                                NaN
# 11                                                NaN
# 12  02/Jan/24 10:11 AM;64251bceb05b4e3e7dabeb51;P0...
# 13  12/Jan/24 9:43 AM;64251bceb05b4e3e7dabeb51;使用显...
# 14  20/Dec/23 9:58 AM;64251bceb05b4e3e7dabeb51;P01...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                             Comment.3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   17/Jan/24 2:06 PM;557058:32c1d8f2-faaf-4956-bd...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  10/Jan/24 6:07 PM;557058:5bc1e774-4804-4009-ab...
# 13                                                NaN
# 14  20/Dec/23 10:23 AM;64251bceb05b4e3e7dabeb51;P0...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                             Comment.4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   18/Jan/24 4:58 PM;557058:5bc1e774-4804-4009-ab...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                             Comment.5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   23/Jan/24 1:21 PM;557058:32c1d8f2-faaf-4956-bd...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                             Comment.6 Status Category  \
# 0                                                 NaN           To Do
# 1                                                 NaN           To Do
# 2                                                 NaN           To Do
# 3                                                 NaN           To Do
# 4                                                 NaN           To Do
# 5                                                 NaN           To Do
# 6                                                 NaN           To Do
# 7   01/Feb/24 9:11 AM;557058:5bc1e774-4804-4009-ab...           To Do
# 8                                                 NaN           To Do
# 9                                                 NaN           To Do
# 10                                                NaN           To Do
# 11                                                NaN           To Do
# 12                                                NaN           To Do
# 13                                                NaN           To Do
# 14                                                NaN           To Do
# 15                                                NaN           To Do
# 16                                                NaN           To Do
# 17                                                NaN           To Do
#
#    Status Category Changed
# 0        08/Mar/24 9:31 AM
# 1        08/Mar/24 9:29 AM
# 2        26/Feb/24 4:34 PM
# 3        26/Feb/24 4:31 PM
# 4       23/Feb/24 12:00 PM
# 5        07/Feb/24 9:10 AM
# 6        02/Feb/24 6:06 PM
# 7        23/Jan/24 1:21 PM
# 8        25/Nov/23 9:02 AM
# 9       25/Nov/23 10:27 AM
# 10      19/Jan/24 10:33 AM
# 11      15/Dec/23 11:55 AM
# 12      02/Jan/24 10:11 AM
# 13       27/Dec/23 4:27 PM
# 14      20/Dec/23 10:23 AM
# 15       28/Dec/23 8:28 AM
# 16       27/Dec/23 4:09 PM
# 17       02/Jan/24 9:39 AM
#
# [18 rows x 124 columns]

# %%
df.columns.values
# Out:
# array(['Summary', 'Issue key', 'Issue id', 'Issue Type', 'Status',
#        'Project key', 'Project name', 'Project type', 'Project lead',
#        'Project lead id', 'Project description', 'Project url',
#        'Priority', 'Resolution', 'Assignee', 'Assignee Id', 'Reporter',
#        'Reporter Id', 'Creator', 'Creator Id', 'Created', 'Updated',
#        'Last Viewed', 'Resolved', 'Affects versions', 'Fix versions',
#        'Fix versions.1', 'Components', 'Due date', 'Votes', 'Labels',
#        'Description', 'Environment', 'Watchers', 'Watchers.1',
#        'Watchers.2', 'Watchers.3', 'Watchers Id', 'Watchers Id.1',
#        'Watchers Id.2', 'Watchers Id.3', 'Original estimate',
#        'Remaining Estimate', 'Time Spent', 'Work Ratio',
#        'Σ Original Estimate', 'Σ Remaining Estimate', 'Σ Time Spent',
#        'Security Level', 'Attachment', 'Attachment.1', 'Attachment.2',
#        'Attachment.3', 'Attachment.4', 'Attachment.5', 'Attachment.6',
#        'Attachment.7', 'Attachment.8', 'Custom field (Affected services)',
#        'Custom field (Allocation)', 'Custom field (App Version)',
#        'Custom field (Approvals)', 'Custom field (Atlas project key)',
#        'Custom field (Atlas project status)', 'Custom field (Category)',
#        'Custom field (Category).1', 'Custom field (Countermeasure)',
#        'Custom field (Custom1)', 'Custom field (Date)',
#        'Custom field (Defect Group)', 'Custom field (Department_whom )',
#        'Custom field (Design)', 'Custom field (Development)',
#        'Custom field (Epic Color)', 'Custom field (Epic Name)',
#        'Custom field (Epic Status)', 'Custom field (Failure location)',
#        'Custom field (Gating Stage)', 'Custom field (Issue color)',
#        'Custom field (Location)', 'Custom field (Locked forms)',
#        'Custom field (Model)', 'Custom field (Open forms)',
#        'Custom field (Opportunity value)', 'Custom field (Parts number)',
#        'Custom field (Progress)', 'Custom field (QE)',
#        'Custom field (RD Analysis)', 'Custom field (Rank)',
#        'Custom field (Recovery Method)', 'Custom field (Request Type)',
#        'Custom field (Request language)',
#        'Custom field (Request participants)',
#        'Custom field (Resolve Date)', 'Custom field (Resolver)',
#        'Custom field (Rework Request form)', 'Satisfaction rating',
#        'Custom field (Satisfaction date)', 'Custom field (Serial Number)',
#        'Custom field (Software Version)', 'Custom field (Stage)',
#        'Custom field (Start date)', 'Custom field (Status)',
#        'Custom field (Story Points)',
#        'Custom field (Story point estimate)',
#        'Custom field (Submitted forms)', 'Custom field (Target end)',
#        'Custom field (Target start)', 'Custom field (Team)',
#        'Custom field (Total forms)', 'Custom field (VendorCR)',
#        'Custom field ([CHART] Date of First Response)',
#        'Custom field ([CHART] Time in Status)',
#        'Custom field (responsible)', 'Custom field (uuid)', 'Comment',
#        'Comment.1', 'Comment.2', 'Comment.3', 'Comment.4', 'Comment.5',
#        'Comment.6', 'Status Category', 'Status Category Changed'],
#       dtype=object)

# %%
df_out = df[['Priority','Issue key','Status','Assignee','Created','Custom field (VendorCR)']]

# %%
df_out.to_csv('Amtran_out.csv')
