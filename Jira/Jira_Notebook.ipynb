# %%
import pandas

# %%
df = pandas.read_csv("Amtran.csv")

# %%
df
# Out:
#                                                Summary       Issue key  \
# 0     [OSD] OSD主菜单上方显示图像模式/输入选择与HDR状态， 上下字体对准方式不统一（如图）  XG32WCMS63-285
# 1                             [OSD]开关HDR功能，OSD部分菜单显示异常  XG32WCMS63-318
# 2               [SYS] 移除信号自动切source时，指示灯先变橙色再变白色，然后出画面  XG32WCMS63-326
# 3     [SYS] 菜单 游戏--ELMB设置-- 清晰位置功能互相切换时画面遮黑开启后，没有对应的作用  XG32WCMS63-297
# 4         [SYS] 显示器AC 或DC开机后 ，按出主菜单上下调节时反应偏慢，5秒左右可恢复正常  XG32WCMS63-328
# ..                                                 ...             ...
# 104                      [OSD]切换到Vietnamese (越南文),菜单乱码  XG32WCMS63-168
# 105                       [OSD]切换到Persian (波斯 语言),菜单乱码  XG32WCMS63-166
# 106       [SYS] 调节Blue Light Filter的项目时反应慢。画面改变后，项目才选中   XG32WCMS63-34
# 107  [OSD] 机台Variable Refresh Rate开启时，机台中提示语与OSD TR...   XG32WCMS63-86
# 108            [OSD] 在HDMIsource 下，拔掉信号时会显示蓝屏并显示器“无信号”  XG32WCMS63-108
#
#      Issue id Issue Type       Status Project key             Project name  \
# 0      124072        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 1      124155        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 2      124173        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 3      124100        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 4      124176        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# ..        ...        ...          ...         ...                      ...
# 104    123551        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 105    123549        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 106    123273        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 107    123337        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
# 108    123382        Bug  In Progress  XG32WCMS63  ASUS XG32WCMS_CSOT_2024
#
#     Project type Project lead                              Project lead id  \
# 0       business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 1       business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 2       business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 3       business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 4       business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# ..           ...          ...                                          ...
# 104     business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 105     business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 106     business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 107     business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
# 108     business  Jason Huang  557058:33e8fddc-2108-410c-95ff-830c0f242236
#
#      ... Custom field (responsible)  Custom field (uuid)  \
# 0    ...                        NaN                  NaN
# 1    ...                        NaN                  NaN
# 2    ...                        NaN                  NaN
# 3    ...                        NaN                  NaN
# 4    ...                        NaN                  NaN
# ..   ...                        ...                  ...
# 104  ...                        NaN                  NaN
# 105  ...                        NaN                  NaN
# 106  ...                        NaN                  NaN
# 107  ...                        NaN                  NaN
# 108  ...                        NaN                  NaN
#
#                                                Comment  \
# 0                                                  NaN
# 1    03/Mar/24 12:03 AM;557058:33e8fddc-2108-410c-9...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#                                              Comment.1  \
# 0                                                  NaN
# 1    04/Mar/24 8:19 AM;61dbedf1326554006c49c765;做了R...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#                                              Comment.2  \
# 0                                                  NaN
# 1    04/Mar/24 11:11 AM;557058:33e8fddc-2108-410c-9...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#                                              Comment.3  \
# 0                                                  NaN
# 1    04/Mar/24 11:41 AM;61dbedf1326554006c49c765;对比...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#                                              Comment.4  \
# 0                                                  NaN
# 1    04/Mar/24 11:54 AM;61dbedf1326554006c49c765;HD...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#                                              Comment.5 Status Category  \
# 0                                                  NaN     In Progress
# 1    08/Mar/24 9:59 AM;557058:33e8fddc-2108-410c-95...     In Progress
# 2                                                  NaN     In Progress
# 3                                                  NaN     In Progress
# 4                                                  NaN     In Progress
# ..                                                 ...             ...
# 104                                                NaN     In Progress
# 105                                                NaN     In Progress
# 106                                                NaN     In Progress
# 107                                                NaN     In Progress
# 108                                                NaN     In Progress
#
#     Status Category Changed
# 0        07/Mar/24 11:02 AM
# 1         08/Mar/24 9:58 AM
# 2        04/Mar/24 10:53 AM
# 3         08/Mar/24 2:39 PM
# 4         08/Mar/24 5:57 PM
# ..                      ...
# 104       05/Feb/24 4:14 PM
# 105       05/Feb/24 3:54 PM
# 106       02/Feb/24 3:15 PM
# 107       01/Feb/24 9:37 AM
# 108       30/Jan/24 2:33 PM
#
# [109 rows x 130 columns]

# %%
df.columns.values
# Out:
# array(['Summary', 'Issue key', 'Issue id', 'Issue Type', 'Status',
#        'Project key', 'Project name', 'Project type', 'Project lead',
#        'Project lead id', 'Project description', 'Project url',
#        'Priority', 'Resolution', 'Assignee', 'Assignee Id', 'Reporter',
#        'Reporter Id', 'Creator', 'Creator Id', 'Created', 'Updated',
#        'Last Viewed', 'Resolved', 'Affects versions', 'Fix versions',
#        'Fix versions.1', 'Components', 'Due date', 'Votes', 'Labels',
#        'Description', 'Environment', 'Watchers', 'Watchers.1',
#        'Watchers.2', 'Watchers.3', 'Watchers Id', 'Watchers Id.1',
#        'Watchers Id.2', 'Watchers Id.3', 'Original estimate',
#        'Remaining Estimate', 'Time Spent', 'Work Ratio',
#        'Σ Original Estimate', 'Σ Remaining Estimate', 'Σ Time Spent',
#        'Security Level', 'Attachment', 'Attachment.1', 'Attachment.2',
#        'Attachment.3', 'Attachment.4', 'Attachment.5', 'Attachment.6',
#        'Attachment.7', 'Attachment.8', 'Custom field (Affected services)',
#        'Custom field (Allocation)', 'Custom field (App Version)',
#        'Custom field (Approvals)', 'Custom field (Atlas project key)',
#        'Custom field (Atlas project status)', 'Custom field (Category)',
#        'Custom field (Category).1', 'Custom field (Countermeasure)',
#        'Custom field (Custom1)', 'Custom field (Date)',
#        'Custom field (Defect Group)', 'Custom field (Department_whom )',
#        'Custom field (Design)', 'Custom field (Development)',
#        'Custom field (Epic Color)', 'Custom field (Epic Name)',
#        'Custom field (Epic Status)', 'Custom field (Failure location)',
#        'Custom field (Gating Stage)', 'Custom field (Issue color)',
#        'Custom field (Location)', 'Custom field (Locked forms)',
#        'Custom field (Model)', 'Custom field (Open forms)',
#        'Custom field (Opportunity value)', 'Custom field (Parts number)',
#        'Custom field (Progress)', 'Custom field (QE)',
#        'Custom field (RD Analysis)', 'Custom field (Rank)',
#        'Custom field (Recovery Method)', 'Custom field (Request Type)',
#        'Custom field (Request language)',
#        'Custom field (Request participants)',
#        'Custom field (Resolve Date)', 'Custom field (Resolver)',
#        'Custom field (Rework Request form)', 'Satisfaction rating',
#        'Custom field (Satisfaction date)', 'Custom field (Serial Number)',
#        'Custom field (Software Version)', 'Custom field (Stage)',
#        'Custom field (Start date)', 'Custom field (Status)',
#        'Custom field (Story Points)',
#        'Custom field (Story point estimate)',
#        'Custom field (Submitted forms)', 'Custom field (Target end)',
#        'Custom field (Target start)', 'Custom field (Team)',
#        'Custom field (Total forms)', 'Custom field (VendorCR)',
#        'Custom field ([CHART] Date of First Response)',
#        'Custom field ([CHART] Time in Status)',
#        'Custom field (responsible)', 'Custom field (uuid)', 'Comment',
#        'Comment.1', 'Comment.2', 'Comment.3', 'Comment.4', 'Comment.5',
#        'Comment.6', 'Status Category', 'Status Category Changed'],
#       dtype=object)

# %%
df_out = df[['Priority','Issue key','Status','Assignee','Created','Custom field (VendorCR)']]

# %%
df_out
# Out:
#     Priority       Issue key       Status     Assignee             Created  \
# 0          C  XG32WCMS63-285  In Progress     Bruce Wu  29/Feb/24 10:03 AM
# 1          B  XG32WCMS63-318  In Progress  Jason Huang   02/Mar/24 9:56 AM
# 2          B  XG32WCMS63-326  In Progress     Bruce Wu   04/Mar/24 9:19 AM
# 3          B  XG32WCMS63-297  In Progress     Bruce Wu   29/Feb/24 4:22 PM
# 4          C  XG32WCMS63-328  In Progress     Bruce Wu   04/Mar/24 9:52 AM
# ..       ...             ...          ...          ...                 ...
# 104        B  XG32WCMS63-168  In Progress     Bruce Wu  04/Feb/24 10:16 AM
# 105        B  XG32WCMS63-166  In Progress     Bruce Wu   04/Feb/24 8:32 AM
# 106        B   XG32WCMS63-34  In Progress     Bruce Wu   27/Jan/24 1:34 PM
# 107        B   XG32WCMS63-86  In Progress     Bruce Wu  29/Jan/24 11:35 AM
# 108        B  XG32WCMS63-108  In Progress  Jason Huang  30/Jan/24 10:08 AM
#
#                             Custom field (VendorCR)
# 0    https://amtran.atlassian.net/browse/MONMTK-689
# 1                                               NaN
# 2    https://amtran.atlassian.net/browse/MONMTK-661
# 3    https://amtran.atlassian.net/browse/MONMTK-696
# 4    https://amtran.atlassian.net/browse/MONMTK-697
# ..                                              ...
# 104                                             NaN
# 105                                             NaN
# 106                                             NaN
# 107                                             NaN
# 108                                             NaN
#
# [109 rows x 6 columns]

# %%
df_out.to_csv('Amtran_out.csv', index=False)
